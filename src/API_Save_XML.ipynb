# %% [markdown]
# #### This code requests the Elsevier API for full-text XML: waiting for EPFL token to be able to use all articles, now only OA.
#
# #### The files are saved into the XMLs folder
#
# #### Pre-filter the articles by keywords, date, and not review articles

# %%
import requests, json, pathlib
from datetime import datetime

# Config
API_KEY    = "2666c3270101dc6d670514f592d567a8" 
INST_TOKEN = ""  
BASE       = "https://api.elsevier.com"


OUT_DIR = pathlib.Path("../data/XMLs")

# Headers for JSON and XML requests
HEADERS_JSON = {"Accept": "application/json", "X-ELS-APIKey": API_KEY}
HEADERS_XML  = {"Accept": "text/xml",          "X-ELS-APIKey": API_KEY}
if INST_TOKEN:
    HEADERS_JSON["X-ELS-Insttoken"] = INST_TOKEN
    HEADERS_XML["X-ELS-Insttoken"]  = INST_TOKEN

# functions
def search_sciencedirect(query, count=25, offset=0):
    """Search ScienceDirect and return a list of dicts with basic article info."""
    url = f"{BASE}/content/search/sciencedirect"
    params = {"query": query, "count": str(count), "offset": str(offset), "show": "all"}
    r = requests.get(url, params=params, headers=HEADERS_JSON, timeout=30)

    print("HTTP", r.status_code, "-", r.url)
    if r.status_code != 200:
        print("Body snippet:", r.text[:300])
        r.raise_for_status()

    data = r.json()
    total = data.get("search-results", {}).get("opensearch:totalResults")
    print("totalResults:", total)

    entries = data.get("search-results", {}).get("entry", []) or []
    results = []
    for e in entries:
        results.append({
            "title":   e.get("dc:title"),
            "journal": e.get("prism:publicationName"),
            "date":    e.get("prism:coverDate"),
            "doi":     e.get("prism:doi"),
            "pii":     e.get("pii") or (e.get("dc:identifier","").replace("PII:","") if "PII:" in e.get("dc:identifier","") else None),
            "subtype": (e.get("subtypeDescription") or e.get("prism:aggregationType") or "").lower(),
        })
    return results

def save_xml_for(doi=None, pii=None):
    """Download XML from Elsevier API and save it in OUT_DIR."""

    headers = {"Accept": "text/xml", "X-ELS-APIKey": API_KEY}
    if INST_TOKEN:
        headers["X-ELS-Insttoken"] = INST_TOKEN

    if doi:
        url = f"{BASE}/content/article/doi/{doi}"
        fname = OUT_DIR / f"{doi.replace('/', '_')}.xml"
    elif pii:
        url = f"{BASE}/content/article/pii/{pii}"
        fname = OUT_DIR / f"{pii}.xml"
    else:
        print("No DOI or PII provided.")
        return

    r = requests.get(url, headers=headers, timeout=60)
    if r.status_code == 200 and r.text.strip():
        fname.write_text(r.text, encoding="utf-8")
        print("Saved:", fname)
    else:
        print("Did not save. HTTP:", r.status_code)

def year(date_str):
    """Return the year as int from a date string like '2021-06-15'."""
    return int(date_str[:4]) if date_str and date_str[:4].isdigit() else 0

# main code
if __name__ == "__main__":
    # Pre-filter the articles requested by keywords and OA FOR NOW!!
    query = 'TITLE-ABSTR-KEY("carbon capture") AND membrane AND permeance AND selectivity AND combustion AND polymer AND GPU AND OPENACCESS(1)'
    hits = search_sciencedirect(query, count=25)

    # Filter hits for recent articles and not reviews
    keep = [h for h in hits if year(h["date"]) >= 2010 and "review" not in h["subtype"]]
    print(f"kept {len(keep)} of {len(hits)}")

    # Print a summary of kept results
    for k in keep:
        print("-", k["date"], k["journal"], "|", k["title"][:80], "...", k["doi"] or k["pii"])

    # Save XML for each kept article that has a DOI or PII
    MAX_SAVE = 3 # Limit to 3 XMLs to avoid hammering the API
    for i, k in enumerate(keep):
        if i >= MAX_SAVE:
            print(f"Reached limit of {MAX_SAVE} XMLs, stopping.")
            break
        save_xml_for(doi=k["doi"], pii=k["pii"])
# Out:
# HTTP 200 - https://api.elsevier.com/content/search/sciencedirect?query=TITLE-ABSTR-KEY%28%22carbon+capture%22%29+AND+membrane+AND+permeance+AND+selectivity+AND+combustion+AND+polymer+AND+GPU+AND+OPENACCESS%281%29&count=25&offset=0&show=all
# totalResults: 131
# kept 25 of 25
# - 2024-02-29 Journal of Membrane Science | Breaking barriers: Unleashing CO<ce:inf loc=post>2</ce:inf> selectivity with ult ... 10.1016/j.memsci.2023.122272
# - 2024-12-31 Process Safety and Environmental Protection | Thin film nanocomposite membranes based on renewable polymer Pebax® and zeolitic ... 10.1016/j.psep.2024.10.053
# - 2025-03-31 Green Energy & Environment | Facilitated transport membranes in post-combustion carbon capture: Recent advanc ... 10.1016/j.gee.2024.04.010
# - 2025-04-30 Journal of Membrane Science | Recent progress in thin film composite membranes based on the polymer of intrins ... 10.1016/j.memsci.2025.123844
# - 2023-04-15 Journal of Membrane Science | Hydrogen-sieving zeolitic films by coating zeolite nanosheets on porous polymeri ... 10.1016/j.memsci.2023.121454
# - 2024-06-30 Carbon Capture Science & Technology | Recent progress on functional polymeric membranes for CO<ce:inf loc=post>2</ce:i ... 10.1016/j.ccst.2024.100204
# - 2025-01-31 Journal of Membrane Science | Mixed matrix and thin-film nanocomposite membranes of PIM-1 and hydrolyzed PIM-1 ... 10.1016/j.memsci.2024.123388
# - 2024-04-15 Heliyon | Statistical analysis of CO<ce:inf loc=post>2</ce:inf>/N<ce:inf loc=post>2</ce:in ... 10.1016/j.heliyon.2024.e29069
# - 2016-10-31 Green Energy & Environment | High-permeance crosslinked PTMSP thin-film composite membranes as supports for C ... 10.1016/j.gee.2016.10.002
# - 2023-08-05 Journal of Membrane Science | CO<ce:inf loc=post>2</ce:inf> separation using thin film composite membranes of  ... 10.1016/j.memsci.2023.121697
# - 2014-12-31 Energy Procedia | Enhancing Membrane Permeability for CO<ce:inf loc=post>2</ce:inf> Capture Throug ... 10.1016/j.egypro.2014.11.021
# - 2014-12-31 Energy Procedia | CO<ce:inf loc=post>2</ce:inf> Separation with Nano-thick Polymeric Membrane for  ... 10.1016/j.egypro.2014.11.025
# - 2024-01-19 Polymer | Effects of metal acetate addition on the gas separation properties of polymers o ... 10.1016/j.polymer.2023.126556
# - 2018-10-15 Journal of Membrane Science | Ultrahigh-permeance PIM-1 based thin film nanocomposite membranes on PAN support ... 10.1016/j.memsci.2018.07.089
# - 2024-12-31 Advanced Membranes | Progress in design of halloysite nanotubes-polymer nanocomposite membranes and t ... 10.1016/j.advmem.2024.100091
# - 2020-01-31 Green Energy & Environment | PVA/PVP blend polymer matrix for hosting carriers in facilitated transport membr ... 10.1016/j.gee.2019.10.001
# - 2022-11-30 Ultrasonics Sonochemistry | Ultrasonically synthesized MOFs for modification of polymeric membranes: A criti ... 10.1016/j.ultsonch.2022.106202
# - 2022-06-30 Current Opinion in Chemical Engineering | Seeking synergy in membranes: blends and mixtures with polymers of intrinsic mic ... 10.1016/j.coche.2022.100792
# - 2024-03-31 Carbon Capture Science & Technology | Mixed-matrix membranes comprising porous organic molecular cage for efficient CO ... 10.1016/j.ccst.2023.100152
# - 2024-06-30 Carbon Capture Science & Technology | Techno-economic process optimization for a range of membrane performances: What  ... 10.1016/j.ccst.2023.100182
# - 2018-03-15 Journal of Membrane Science | High performance mixed matrix membranes (MMMs) composed of ZIF-94 filler and 6FD ... 10.1016/j.memsci.2017.12.033
# - 2025-10-31 Journal of Environmental Chemical Engineering | Life cycle assessment and multi-objective optimization of biogas upgrading using ... 10.1016/j.jece.2025.117688
# - 2016-10-31 Green Energy & Environment | Techno-economical evaluation of membrane based biogas upgrading system: A compar ... 10.1016/j.gee.2016.10.003
# - 2024-06-30 Carbon Capture Science & Technology | The Impact of Cement Plant Air Ingress on Membrane-Based CO<ce:inf loc=post>2</c ... 10.1016/j.ccst.2024.100201
# - 2021-08-31 Journal of Environmental Chemical Engineering | Phase inversion method for the preparation of Pebax® 3533 thin film membranes fo ... 10.1016/j.jece.2021.105624
# Saved: ../data/XMLs/10.1016_j.memsci.2023.122272.xml
# Saved: ../data/XMLs/10.1016_j.psep.2024.10.053.xml
# Saved: ../data/XMLs/10.1016_j.gee.2024.04.010.xml
# Reached limit of 3 XMLs, stopping.
